# %%
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import gridspec

# %%
git_data = pd.read_html("https://github.com/yashbhutoria/PCE-CS-III-ML-Club/blob/master/README.md")
assign_data = pd.read_csv("https://docs.google.com/spreadsheets/d/12ctiyShx00Chea0AZ0C9Z1wrKFSunZWUKT6gZmnHdaw/export?format=csv&id=12ctiyShx00Chea0AZ0C9Z1wrKFSunZWUKT6gZmnHdaw&gid=1027535130")

# %%
git_data = git_data[0].append(git_data[1])

# %%
git_data['Registration No.'] = git_data['Registration No.'].str.upper()
git_data.head()
# Out:
#    S.No.  Stars ⭐️ Registration No.             Name  \
# 0      1       NaN       PCE16CE129  Abhishek Sharma
# 1      2       6.0       PCE16CE006    Aditya Rajora
# 2      3       1.0       PCE16CE023      Ayush Kumar
# 3      4       NaN       PCE16CE030      Chahat Jain
# 4      5       NaN       PCE16CE031      Chayan Jain
#
#                                        Git Repo Link
# 0  https://github.com/Abhi2819sharma/MY-ML-Practi...
# 1       https://github.com/Adityarajora/MYMLPractice
# 2        https://github.com/Ayushkr99/My-Ml-Practice
# 3   https://github.com/Chahat1996/MY-ML-Practice.git
# 4                                                NaN

# %%
assign_data.sample(5)
# Out:
#                Timestamp                    Email Address Registration Number  \
# 0    06-01-2019 15:08:00  2016pcecepiyush075@poornima.org          PCE16CE075
# 124   1/16/2019 23:52:42  2016pcecemahima061@poornima.org          PCE16CE061
# 104   1/13/2019 10:11:45  2016pceceaditya006@poornima.org          PCE16CE006
# 90    1/11/2019 23:13:20            distijain98@gmail.com         PCE16CE036
# 22   06-01-2019 22:36:33             7790pulkit@gmail.com          pce16ce082
#
#      Assignment Number
# 0                    1
# 124                  5
# 104                  2
# 90                   3
# 22                   1

# %%
assign_data.loc[assign_data['Email Address'] == "2016pceceaditya006@poornima.org" ]
# Out:
#               Timestamp                    Email Address Registration Number  \
# 104  1/13/2019 10:11:45  2016pceceaditya006@poornima.org          PCE16CE006
# 105  1/13/2019 10:12:03  2016pceceaditya006@poornima.org          PCE16CE006
# 106  1/13/2019 10:12:21  2016pceceaditya006@poornima.org          PCE16CE006
# 107  1/13/2019 10:12:47  2016pceceaditya006@poornima.org          PCE16CE006
# 108  1/13/2019 10:12:56  2016pceceaditya006@poornima.org          PCE16CE006
#
#      Assignment Number
# 104                  2
# 105                  3
# 106                  4
# 107                  5
# 108                  6

# %%
assign_data.loc[assign_data['Assignment Number'] == 123456 , 'Assignment Number'] = 1

# %%
assign_data.loc[assign_data['Email Address'] == "2016pceceaditya006@poornima.org" ]
# Out:
#               Timestamp                    Email Address Registration Number  \
# 104  1/13/2019 10:11:45  2016pceceaditya006@poornima.org          PCE16CE006
# 105  1/13/2019 10:12:03  2016pceceaditya006@poornima.org          PCE16CE006
# 106  1/13/2019 10:12:21  2016pceceaditya006@poornima.org          PCE16CE006
# 107  1/13/2019 10:12:47  2016pceceaditya006@poornima.org          PCE16CE006
# 108  1/13/2019 10:12:56  2016pceceaditya006@poornima.org          PCE16CE006
#
#      Assignment Number
# 104                  2
# 105                  3
# 106                  4
# 107                  5
# 108                  6

# %%
assign_data.loc[assign_data['Registration Number'] == "PCE16CE052" ]
# Out:
#                Timestamp                  Email Address Registration Number  \
# 28   07-01-2019 00:44:53           msg4jaya99@gmail.com          PCE16CE052
# 29   07-01-2019 00:45:18           msg4jaya99@gmail.com          PCE16CE052
# 30   07-01-2019 00:45:38           msg4jaya99@gmail.com          PCE16CE052
# 78    1/11/2019 14:39:33  2016pcecejaya052@poornima.org          PCE16CE052
# 79    1/11/2019 14:39:34  2016pcecejaya052@poornima.org          PCE16CE052
# 96     1/12/2019 2:15:33  2016pcecejaya052@poornima.org          PCE16CE052
# 110   1/13/2019 20:52:56  2016pcecejaya052@poornima.org          PCE16CE052
#
#      Assignment Number
# 28                   1
# 29                   2
# 30                   3
# 78                   4
# 79                   4
# 96                   5
# 110                  6

# %%
assign_data.drop(assign_data[assign_data.Timestamp == '1/18/2019 1:09:40'].index, inplace=True)

# %%
assign_data.loc[assign_data['Registration Number'] == "PCE16CE052" ]
# Out:
#                Timestamp                  Email Address Registration Number  \
# 28   07-01-2019 00:44:53           msg4jaya99@gmail.com          PCE16CE052
# 29   07-01-2019 00:45:18           msg4jaya99@gmail.com          PCE16CE052
# 30   07-01-2019 00:45:38           msg4jaya99@gmail.com          PCE16CE052
# 78    1/11/2019 14:39:33  2016pcecejaya052@poornima.org          PCE16CE052
# 79    1/11/2019 14:39:34  2016pcecejaya052@poornima.org          PCE16CE052
# 96     1/12/2019 2:15:33  2016pcecejaya052@poornima.org          PCE16CE052
# 110   1/13/2019 20:52:56  2016pcecejaya052@poornima.org          PCE16CE052
#
#      Assignment Number
# 28                   1
# 29                   2
# 30                   3
# 78                   4
# 79                   4
# 96                   5
# 110                  6

# %%
assign_data['Registration Number'] = assign_data['Registration Number'].str.upper()
assign_data.head()
# Out:
#              Timestamp                    Email Address Registration Number  \
# 0  06-01-2019 15:08:00  2016pcecepiyush075@poornima.org          PCE16CE075
# 1  06-01-2019 15:08:55  2016pcecepiyush075@poornima.org          PCE16CE075
# 2  06-01-2019 15:38:30   2016pcecemegha064@poornima.org          PCE16CE064
# 3  06-01-2019 16:40:04          sanjolijain04@gmail.com          PCE16CE307
# 4  06-01-2019 18:46:46        swapnilsingh674@gmail.com          PCE16CE106
#
#    Assignment Number
# 0                  1
# 1                  2
# 2                  1
# 3                  2
# 4                  1

# %%
frame = assign_data.groupby('Registration Number')[["Assignment Number"]].max()

# %%
frame = frame.rename(columns= {0: 'list'})

# %%
frame.sort_values("Assignment Number",ascending = False).head()
# Out:
#                      Assignment Number
# Registration Number
# PCE16CE006                           6
# PCE16CE068                           6
# PCE16CE102                           6
# PCE16CE094                           6
# PCE16CE088                           6

# %%
final = pd.merge(git_data, frame, how='inner', left_on = 'Registration No.', right_on = 'Registration Number')

# %%
final.head()
# Out:
#    S.No.  Stars ⭐️ Registration No.             Name  \
# 0      1       NaN       PCE16CE129  Abhishek Sharma
# 1      2       6.0       PCE16CE006    Aditya Rajora
# 2      3       1.0       PCE16CE023      Ayush Kumar
# 3      4       NaN       PCE16CE030      Chahat Jain
# 4      6       NaN       PCE16CE034    Diksha Bothra
#
#                                        Git Repo Link  Assignment Number
# 0  https://github.com/Abhi2819sharma/MY-ML-Practi...                  3
# 1       https://github.com/Adityarajora/MYMLPractice                  6
# 2        https://github.com/Ayushkr99/My-Ml-Practice                  6
# 3   https://github.com/Chahat1996/MY-ML-Practice.git                  3
# 4     https://github.com/dikshabothra/My-ML-Practice                  4

# %%
final=final.drop(columns=['S.No.','Registration No.','Git Repo Link',])
final.sample(5)
# Out:
#     Stars ⭐️              Name  Assignment Number
# 0        NaN   Abhishek Sharma                  3
# 16       NaN    Sakshi Agarwal                  6
# 12       4.0    Piyush Vaishya                  6
# 9        NaN  Mahima Sukhlecha                  5
# 20       NaN    Sudhanshu Jain                  6

# %%
final = final.sort_values(by=['Assignment Number'], ascending=False)

# %%
final.head()
# Out:
#     Stars ⭐️            Name  Assignment Number
# 12       4.0  Piyush Vaishya                  6
# 15       NaN    Sahil Chopra                  6
# 2        1.0     Ayush Kumar                  6
# 22       5.0   Swapnil Singh                  6
# 21       3.0     Suraj Kumar                  6

# %%
stars = final.loc[final['Stars ⭐️'] >= 1.0 ].sort_values('Stars ⭐️')
stars
# Out:
#     Stars ⭐️              Name  Assignment Number
# 2        1.0       Ayush Kumar                  6
# 6        1.0      Eakta Sharma                  6
# 18       1.0   Shivansh Mathur                  4
# 14       1.0    Rishina Dargar                  3
# 17       1.0      Sanjoli Jain                  2
# 11       2.0       Mohit Saini                  6
# 21       3.0       Suraj Kumar                  6
# 12       4.0    Piyush Vaishya                  6
# 22       5.0     Swapnil Singh                  6
# 1        6.0     Aditya Rajora                  6
# 23       6.0    Alfaij Mansuri                  3
# 19       7.0  Shruti Ganeriwal                  6
# 24       9.0    Kuldeep Tailor                  5

# %%
length = list(stars["Name"])
length
# Out:
# ['Ayush Kumar',
#  'Eakta Sharma',
#  'Shivansh Mathur',
#  'Rishina Dargar',
#  'Sanjoli Jain',
#  'Mohit Saini',
#  'Suraj Kumar',
#  'Piyush Vaishya',
#  'Swapnil Singh',
#  'Aditya Rajora',
#  'Alfaij Mansuri',
#  'Shruti Ganeriwal',
#  'Kuldeep Tailor']

# %%
submitted = list(final["Name"])

# %%
all_members = list(git_data["Name"])

# %%
not_submitted = [x for x in all_members if x not in submitted]
str1 = '\n'.join(map(str, not_submitted))
print(str1)
# Out:
# Chayan Jain
# Mohit Agarwal

# %%
plt.figure(figsize=(15, 10))
gs=gridspec.GridSpec(4,6)
gs.update(wspace=0.0, hspace=0.0)


plt.subplot(gs[0,0])
plt.xticks(())
plt.yticks(())
plt.text(0.5, 0.5, 
         'Logo\nComing\n  Soon', 
         ha='center', va='center',
         fontsize=20, 
         color="black")
#ax1=plt.subplot(gs[0,0])
#ax1.text(0.2, 0.5, '  Logo\nComing\n  Soon',verticalalignment='center', horizontalalignment='left',color='black', fontsize=18)
#ax1.axis('off')

plt.subplot(gs[1,0])
plt.xticks(())
plt.yticks(())
plt.text(0.5, 0.5, 
         "Stars Earned\n\n  {}".format(final['Stars ⭐️'].sum()), 
         ha='center', va='center',
         fontsize=18, 
         color="black")
#ax2 = plt.subplot(gs[1,0])
#ax2.text(0.01, 0.6, "Stars Earned\n\n     {}".format(final['Stars ⭐️'].sum()),verticalalignment='center', horizontalalignment='left',color='black', fontsize=17)
#ax2.axis('off')



plt.subplot(gs[2:4,0])
plt.xticks(())
plt.yticks(())
plt.text(0.5, 0.5, 
         "Submissions\n\n {}".format(final['Assignment Number'].sum()), 
         ha='center', va='center',
         fontsize=18, 
         color="black")
#ax3 = plt.subplot(gs[2:4,0])
#ax3.text(0.05, 0.6, "Submissions\n\n      {}".format(final['Assignment Number'].sum()),verticalalignment='center', horizontalalignment='left',color='black', fontsize=18)
#ax3.axis('off')

plt.subplot(gs[0:2,1:2])
plt.xticks(())
plt.yticks(())

ax4=plt.subplot(gs[0:2,2:4])
ax4.barh(length,stars['Stars ⭐️'], align="edge", color='yellow')


plt.subplot(gs[2:,1:2])
plt.xticks(())
plt.yticks(())
plt.text(0.5, 0.5, 
         "Members\n\n  {}".format(final['Name'].count()), 
         ha='center', va='center',
         fontsize=20, 
         color="black")
#ax5 = plt.subplot(gs[2:,1:2])
#ax5.text(0.15, 0.6, "Members\n\n      {}".format(final['Name'].count()),verticalalignment='center', horizontalalignment='left',color='black', fontsize=18)
#ax5.axis('off')


ax = plt.subplot(gs[2:,2:4])
ax.set_facecolor("black")
plt.xticks(())
plt.yticks(())
plt.text(0.02, 0.51 ,
         "Students With 0 Submission in Form   \n\n{}\n\n\n\n\n\n\n\n\n".format(str1), 
         ha='left', va='center',
         fontsize=14, 
         color="red")
#ax6 = plt.subplot(gs[2:,2:4])
#ax6.text(0.01, 0.49, "Students With 0 Submission in Form\n\n{}\n\n\n\n\n\n\n\n\n".format(str1),verticalalignment='center',bbox=dict(facecolor='black', alpha=0.9), horizontalalignment='left',color='red', fontsize=14)
#ax6.axis('off')

plt.subplot(gs[:,4:])
plt.xticks(())
plt.yticks(())
ax=plt.table(cellText=final[['Name','Assignment Number']].values,colLabels=['Names','Assginment \n Done'],colWidths = [0.6,0.4],cellLoc = 'left',loc='center')
ax.auto_set_font_size(False)
ax.set_fontsize(11)
ax.scale(1,1.7)
#ax7.axis('off')
